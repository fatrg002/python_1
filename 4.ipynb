# %%
import random

for i in range(101):
    r=random.randint(1,1500)
    print("第" ,i ,"次產生隨機整數:" , r)
# Out:
# 第 0 次產生隨機整數: 687
# 第 1 次產生隨機整數: 51
# 第 2 次產生隨機整數: 370
# 第 3 次產生隨機整數: 71
# 第 4 次產生隨機整數: 811
# 第 5 次產生隨機整數: 907
# 第 6 次產生隨機整數: 1465
# 第 7 次產生隨機整數: 513
# 第 8 次產生隨機整數: 688
# 第 9 次產生隨機整數: 1430
# 第 10 次產生隨機整數: 1121
# 第 11 次產生隨機整數: 413
# 第 12 次產生隨機整數: 1193
# 第 13 次產生隨機整數: 598
# 第 14 次產生隨機整數: 930
# 第 15 次產生隨機整數: 868
# 第 16 次產生隨機整數: 1296
# 第 17 次產生隨機整數: 979
# 第 18 次產生隨機整數: 806
# 第 19 次產生隨機整數: 1307
# 第 20 次產生隨機整數: 386
# 第 21 次產生隨機整數: 625
# 第 22 次產生隨機整數: 786
# 第 23 次產生隨機整數: 882
# 第 24 次產生隨機整數: 298
# 第 25 次產生隨機整數: 632
# 第 26 次產生隨機整數: 30
# 第 27 次產生隨機整數: 620
# 第 28 次產生隨機整數: 35
# 第 29 次產生隨機整數: 1331
# 第 30 次產生隨機整數: 693
# 第 31 次產生隨機整數: 85
# 第 32 次產生隨機整數: 1391
# 第 33 次產生隨機整數: 500
# 第 34 次產生隨機整數: 586
# 第 35 次產生隨機整數: 736
# 第 36 次產生隨機整數: 538
# 第 37 次產生隨機整數: 62
# 第 38 次產生隨機整數: 810
# 第 39 次產生隨機整數: 1480
# 第 40 次產生隨機整數: 1429
# 第 41 次產生隨機整數: 1449
# 第 42 次產生隨機整數: 1127
# 第 43 次產生隨機整數: 317
# 第 44 次產生隨機整數: 559
# 第 45 次產生隨機整數: 1088
# 第 46 次產生隨機整數: 1339
# 第 47 次產生隨機整數: 689
# 第 48 次產生隨機整數: 690
# 第 49 次產生隨機整數: 1404
# ...
